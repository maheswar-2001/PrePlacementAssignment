# %%
Assignemnt 9 
 Question :1
class Solution {
    public boolean isPowerOfTwo(int n)  {
        if(n==0)return false;

        while(n!=1)
        {
            if(n%2!=0)
                return false;
            n/=2;
        }
        return true;
    }
}

# %%
Question 2:
import java.util.Scanner;
public class sum_n
{
    public static int sum(int n)
    {
     if(n==1)return 1;
     return n+sum(n-1);
    }
    public static void main(String[] args)
    {
        Scanner ss = new Scanner(System.in);
        System.out.println("Enter a number");
        int n = ss.nextInt();
        System.out.println("Sum is: "+sum(n));
    }
}

# %%
Question 3:

public class factorial
{
    public static int fact(int n)
    {
        if(n==1)return 1;
        return n*fact(n-1);
    }

    public static void main(String[] args) {
        int x =6;
        System.out.println("Factorial is: "+fact(x));
    }
}

# %%
Question 4:

public class power
{
    public static int pow(int num,int pow)
    {
        if(pow == 1)return num;
        return num*pow(num,pow-1);
    }

    public static void main(String[] args) {
        int n =5;
        int p = 4;
        System.out.println("Result is:"+pow(n,p));
    }
}

# %%
Question 5:

public class max_recurssion
{
    public static int findMax(int arr[],int i)
    {
        if(i==arr.length)return 0;
        int max =arr[i];
        int rmax = findMax(arr,i+1);
        rmax = Math.max(rmax,max);
        return rmax;
    }

    public static void main(String[] args) {
        int a[]={29,50,40,35,87,45};
        System.out.println("Maximum is: "+findMax(a,0));
    }
}

# %%
Question 6:

public class ap_series
{
    public static int series(int a,int d, int n)
    {
      int sum = a+(n-1)*d;
      return sum;
    }
    public static void main(String[] args)
    {
        int num=5,a=1,d=2;
        System.out.println(series(a,d,num));
    }
}

# %%
Question 7:
    

public class Permutation {

	public static void main(String[] args)
	{
		String str = "ABC";
		int n = str.length();
		Permutation permutation = new Permutation();
		permutation.permute(str, 0, n - 1);
	}

	private void permute(String str, int l, int r)
	{
		if (l == r)
			System.out.println(str);
		else {
			for (int i = l; i <= r; i++) {
				str = swap(str, l, i);
				permute(str, l + 1, r);
				str = swap(str, l, i);
			}
		}
	}

	public String swap(String a, int i, int j)
	{
		char temp;
		char[] charArray = a.toCharArray();
		temp = charArray[i];
		charArray[i] = charArray[j];
		charArray[j] = temp;
		return String.valueOf(charArray);
	}
}

# %%
Question 8:

public class product
{
    public static int product(int arr[],int i)
    {
        if(i==arr.length)return 1;
        return arr[i]*product(arr,i+1);
    }

    public static void main(String[] args) {
        int a[]={1,2,3,4,5};
        System.out.println("Product is: "+product(a,0));
    }
}
